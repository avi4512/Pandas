# %%
import pandas as pd

# %%
df = pd.read_excel("D:\\DataSet\\Marks.xlsx")

# %%
df
# Out:
#     id_no         Name  Telugu  Hindi  English  Maths  Science  Social
# 0    1001          Avi      91     87       82     95       92      92
# 1    1002       Hanuma      92     95       87     88       89      90
# 2    1003        Shiva      96     98       87     88       80      81
# 3    1004         Rama      87     89       92     93       96      98
# 4    1005        Vamsi      93     91       87     84       86      82
# 5    1006      Karthik      93     91       92     85       82      88
# 6    1007        Surya      86     88       89     82       93      95
# 7    1008      Chenchu      83     88       87     92       91      90
# 8    1009        Srinu      91     92       87     86       88      80
# 9    1010        Phani      91     92       87     88       89      86
# 10   1011       Lohith      87     88       82     80       92      95
# 11   1012      Prudhvi      87     87       80     90       87      92
# ...

# %%
df.describe()
# Out:
#             id_no     Telugu      Hindi    English      Maths    Science  \
# count    20.00000  20.000000  20.000000  20.000000  20.000000  20.000000
# mean   1010.50000  89.450000  90.400000  87.800000  87.650000  89.250000
# std       5.91608   3.186732   3.470174   4.287067   5.244295   4.799945
# min    1001.00000  83.000000  83.000000  80.000000  80.000000  80.000000
# 25%    1005.75000  87.000000  88.000000  86.750000  83.500000  87.750000
# 50%    1010.50000  90.000000  91.000000  87.000000  88.000000  89.000000
# 75%    1015.25000  92.000000  92.250000  91.250000  90.500000  92.000000
# max    1020.00000  96.000000  98.000000  96.000000  98.000000  98.000000
#
#           Social
# count  20.000000
# mean   88.950000
# std     5.031218
# min    80.000000
# 25%    86.000000
# 50%    89.500000
# 75%    92.250000
# max    98.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id_no    20 non-null     int64
#  1   Name     20 non-null     object
#  2   Telugu   20 non-null     int64
#  3   Hindi    20 non-null     int64
#  4   English  20 non-null     int64
#  5   Maths    20 non-null     int64
#  6   Science  20 non-null     int64
#  7   Social   20 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 1.4+ KB

# %%
#To get Single Column

df['Name']
# Out:
# 0             Avi
# 1          Hanuma
# 2           Shiva
# 3            Rama
# 4           Vamsi
# 5         Karthik
# 6           Surya
# 7         Chenchu
# 8           Srinu
# 9           Phani
# 10         Lohith
# 11        Prudhvi
# 12         Mukesh
# 13       Sai Koti
# 14     Jaan Reddy
# 15           Mahi
# 16      Siva koti
# 17        Krishna
# 18        Prakash
# 19    Jayavardhan
# Name: Name, dtype: object

# %%
# to get more than one Column 
df[['id_no','Name']]
# Out:
#     id_no         Name
# 0    1001          Avi
# 1    1002       Hanuma
# 2    1003        Shiva
# 3    1004         Rama
# 4    1005        Vamsi
# 5    1006      Karthik
# 6    1007        Surya
# 7    1008      Chenchu
# 8    1009        Srinu
# 9    1010        Phani
# 10   1011       Lohith
# 11   1012      Prudhvi
# 12   1013       Mukesh
# 13   1014     Sai Koti
# 14   1015   Jaan Reddy
# 15   1016         Mahi
# 16   1017    Siva koti
# 17   1018      Krishna
# 18   1019      Prakash
# 19   1020  Jayavardhan

# %%
# Sclicing

df[['id_no','Name']][2:10:2]
# Out:
#    id_no   Name
# 2   1003  Shiva
# 4   1005  Vamsi
# 6   1007  Surya
# 8   1009  Srinu

# %%
# to get single row

df.loc[6]
# Out:
# id_no       1007
# Name       Surya
# Telugu        86
# Hindi         88
# English       89
# Maths         82
# Science       93
# Social        95
# Name: 6, dtype: object

# %%
# To get more than one row
#NOTE: in (.loc[]) last index is also included

df.loc[2:8]
# Out:
#    id_no     Name  Telugu  Hindi  English  Maths  Science  Social
# 2   1003    Shiva      96     98       87     88       80      81
# 3   1004     Rama      87     89       92     93       96      98
# 4   1005    Vamsi      93     91       87     84       86      82
# 5   1006  Karthik      93     91       92     85       82      88
# 6   1007    Surya      86     88       89     82       93      95
# 7   1008  Chenchu      83     88       87     92       91      90
# 8   1009    Srinu      91     92       87     86       88      80

# %%
#iterrows()

for i,r in df.iterrows():
    print("Index {}".format(i))
    print("Data ---> \n{}\n".format(r))
# Out:
# Index 0
# Data --->
# id_no      1001
# Name        Avi
# Telugu       91
# Hindi        87
# English      82
# Maths        95
# Science      92
# Social       92
# Name: 0, dtype: object
#
# Index 1
# Data --->
# id_no        1002
# Name       Hanuma
# Telugu         92
# Hindi          95
# English        87
# Maths          88
# Science        89
# Social         90
# Name: 1, dtype: object
#
# Index 2
# Data --->
# id_no       1003
# Name       Shiva
# Telugu        96
# Hindi         98
# English       87
# Maths         88
# Science       80
# Social        81
# Name: 2, dtype: object
#
# Index 3
# Data --->
# id_no      1004
# Name       Rama
# Telugu       87
# Hindi        89
# English      92
# Maths        93
# Science      96
# Social       98
# Name: 3, dtype: object
#
# Index 4
# Data --->
# id_no       1005
# Name       Vamsi
# Telugu        93
# Hindi         91
# English       87
# Maths         84
# Science       86
# Social        82
# Name: 4, dtype: object
#
# ...

# %%
#Condition Based retrivel

df.loc[df['Telugu'] > 92]
# Out:
#    id_no     Name  Telugu  Hindi  English  Maths  Science  Social
# 2   1003    Shiva      96     98       87     88       80      81
# 4   1005    Vamsi      93     91       87     84       86      82
# 5   1006  Karthik      93     91       92     85       82      88

# %%
#it get the count of numbers marks in telugu > 92
#if it i
(df["Telugu"] > 92).sum()
# Out:
# 3

# %%
#Count
#it return no.of non-null values in the data set
(df['id_no']).count()
# Out:
# 20
